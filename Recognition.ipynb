# %%
#!/bin/bash 
dir_root = "\\Users\\Admin\class\\final\\"
# !copy -r "$dir_root"'saved_models' -d '\\Users'
# Out:
# The system cannot find the file specified.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from final import files
import pathlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-13dd8894c638> in <module>
#       1 import os
# ----> 2 import cv2
#       3 import numpy as np
#       4 import tensorflow as tf
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
def predict_class(img_path, model_path):
    classes= {'Covid': 0, 'Pneumonia':1}
    img = tf.keras.preprocessing.image.load_img(img_path, grayscale=False, 
                                               color_mode="rgb", target_size=(224, 224), 
                                               interpolation="lanczos")
    img = tf.keras.preprocessing.image.img_to_array(img)
    img = np.array([img])  # Convert single image to a batch.
    model = tf.keras.models.load_model(model_path)
    Y_pred = model.predict(img)
    y_pred = np.argmax(Y_pred, axis=1)
    label = [k for k, v in classes.items() if v == y_pred[0]][0]
    plt.imshow(cv2.imread(img_path))
    plt.title('Predicted Class Label: {}'.format(label))
    plt.show()

model_path = 'C:\\Users\\Admin\\class\\final\\saved_models\\Pretrained MobileNetV2\\MobileNetV2-best-model.h5'

# %%
file = files.upload()
file = list(file.keys())[0]
predict_class(file, model_path)
# Out:
#      <input type="file" id="files-3ae713d3-2474-45b3-bf8b-2590910697e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ae713d3-2474-45b3-bf8b-2590910697e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Covid.jpeg to Covid.jpeg

# %%
file = files.upload()
file = list(file.keys())[0]
predict_class(file, model_path)
# Out:
#      <input type="file" id="files-778ce7be-3a82-4a62-9c22-d350cfa272c6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-778ce7be-3a82-4a62-9c22-d350cfa272c6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Pneumonia.jpeg to Pneumonia.jpeg
